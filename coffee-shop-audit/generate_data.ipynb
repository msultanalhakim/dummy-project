# %%
import pandas as pd
import numpy as np

# Membuat Data Produk (Master Data)
data_produk = {
    'product_id': [101, 102, 103, 104, 105],
    'nama_produk': ['Kopi Susu', 'Latte', 'Espresso', 'Tea', 'Mineral Water'],
    'kategori': ['Minuman', 'Minuman', 'Minuman', 'Minuman', 'Air'],
    'harga': [15000, 20000, 18000, 10000, 5000]
}
df_produk = pd.DataFrame(data_produk)
df_produk.to_csv('data_produk.csv', index=False)

# Membuat Data Transaksi (Transaction Data)
data_transaksi = {
    'id_transaksi': np.arange(1, 21),
    'tanggal': np.random.choice(['2025-01-01', '2025-01-02', '2025-01-03'], 20),
    'product_id': [101, 102, 101, 105, 103, 101, 104, 102, 101, 999, # 999 adalah ID palsu (error)
                   103, 102, 105, 101, 102, 103, 104, 101, 105, 102],
    'jumlah_beli': [2, 1, 5, 2, 1, 2, 1, 3, 1, 10,
                    2, 1, 2, 5, 1, 1, 1, 2, 3, 1]
}
df_transaksi = pd.DataFrame(data_transaksi)

# Membuat skenario data hilang (Missing Values)
df_transaksi.loc[5, 'jumlah_beli'] = np.nan 

df_transaksi.to_csv('transaksi_toko.csv', index=False)

print("Dataset siap! File 'transaksi_toko.csv' dan 'data_produk.csv' telah dibuat.")
# Out:
# Dataset siap! File 'transaksi_toko.csv' dan 'data_produk.csv' telah dibuat.
